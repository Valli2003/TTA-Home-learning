# %%
print("Hello World")
# Out:
# Running cells with 'Python 3.9.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'C:/Users/valse/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello Earth")
# Out:
# Hello Earth
